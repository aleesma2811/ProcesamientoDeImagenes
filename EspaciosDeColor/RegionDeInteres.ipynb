# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
chiki = cv.imread(r"c:\Users\Ale Escallada\OneDrive\Documentos\imagenesPI2\chicky_512.png")[:,:,::-1]
plt.imshow(chiki)

# %%
#plt.imshow(np.hstack((chiki, np.zeros_like())))

# %%
# Imagen negra
mask = np.zeros_like(chiki)

# Delimitar zona blanca
mask[30:325, 120:420] = 255

plt.imshow(np.hstack((chiki, mask)))

# %% [markdown]
# Linea 1
#
# Linea2

# %%
plt.imshow(np.bitwise_and(chiki, mask))

# %%
# 2 Iteradores, el primer que lleva la cuenta
for count, i in enumerate(['r', 'g', 'b']):
    histograma = cv.calcHist([chiki], [count], None, [256], [0, 256])
    plt.plot(histograma, i)

# %%
chiki.shape
# Out:
# (512, 512, 3)

# %%
#mask = np.zeros_like(chiki)

mask = np.zeros(chiki.shape[:2], dtype=np.uint8)
mask[30:325, 120:420] = 255
plt.imshow(np.hstack((chiki, mask)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Ale Escallada\UP\PYTHON\Procesamiento_de_imagenes\EspaciosDeColor\RegionDeInteres.ipynb Celda 9 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Ale%20Escallada/UP/PYTHON/Procesamiento_de_imagenes/EspaciosDeColor/RegionDeInteres.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> mask = np.zeros(chiki.shape[:2], dtype=np.uint8)
#       <a href='vscode-notebook-cell:/c%3A/Users/Ale%20Escallada/UP/PYTHON/Procesamiento_de_imagenes/EspaciosDeColor/RegionDeInteres.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> mask[30:325, 120:420] = 255
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ale%20Escallada/UP/PYTHON/Procesamiento_de_imagenes/EspaciosDeColor/RegionDeInteres.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> plt.imshow(np.hstack((chiki, mask)))
#
# File c:\Python311\Lib\site-packages\numpy\core\shape_base.py:359, in hstack(tup, dtype, casting)
# ...

# %%
for count, i in enumerate(['r', 'g', 'b']):
    histograma = cv.calcHist([chiki], [count], mask, [256], [0, 256])
    plt.plot(histograma, i)

# %%
bin(32)
# Out:
# '0b100000'
