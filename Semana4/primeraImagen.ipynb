# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
imagen = cv.imread(r"c:\Users\Ale Escallada\OneDrive\Documentos\imagenesPI\chicky_512.png")
#OpenCV BGR
#plt RGB
#OpenCv interpreta azul como rojo

# %%
type(imagen)
# Out:
# numpy.ndarray

# %%
plt.imshow(imagen)

# %%
#Función de cv para cambiar de color
imagen = cv.cvtColor(imagen, cv.COLOR_BGR2RGB)
plt.imshow(imagen)

# %%
imagen.size
# Out:
# 786432

# %%
imagen.shape
# Out:
# (512, 512, 3)

# %%
#cmap
plt.imshow(imagen[200:,200:,0],cmap="gray")

# %%
for i in imagen:
    print(i)
# Out:
# [[64 62 64]
#  [64 62 64]
#  [65 62 62]
#  ...
#  [14 37 72]
#  [16 36 70]
#  [20 37 73]]
# [[66 65 65]
#  [67 65 65]
#  [67 66 64]
#  ...
#  [19 40 73]
#  [19 39 74]
#  [17 37 72]]
# [[65 65 64]
#  [68 68 66]
#  [69 68 66]
#  ...
#  [21 40 73]
#  [22 43 77]
#  [18 41 75]]
# [[61 61 60]
#  [61 61 60]
#  [61 60 60]
#  ...
#  [20 42 75]
#  [20 41 76]
#  [17 38 74]]
# [[58 58 58]
#  [59 59 59]
#  [62 62 62]
#  ...
#  [22 43 77]
#  [19 38 73]
#  [17 36 71]]
# [[60 60 60]
#  [61 61 61]
#  [60 60 60]
#  ...
#  [18 41 74]
#  [18 40 73]
#  [21 41 74]]
# [[58 58 58]
#  [58 58 58]
#  [56 56 56]
#  ...
#  [23 47 81]
#  [21 44 77]
#  [27 49 81]]
# [[57 57 60]
#  [56 56 58]
#  [55 55 56]
#  ...
#  [25 51 85]
#  [21 47 79]
#  [27 53 83]]
# [[58 58 60]
#  [57 58 60]
#  [60 61 63]
#  ...
#  [19 44 79]
#  [18 42 77]
#  [21 44 78]]
# [[58 60 58]
#  [59 61 61]
#  [60 61 62]
#  ...
#  [18 42 77]
#  [21 45 78]
#  [22 44 78]]
# [[58 60 58]
#  [60 62 61]
#  [62 64 63]
#  ...
#  [21 44 77]
#  [29 51 82]
# ...

# %%
#for pixel in range (3):
#    for pixel2 in range (512):
#        for pixel3 in range(512):
#            print(imagen[pixel3, pixel2, pixel])
#    print("\n")
#print("\n")

# %%
negra = np.zeros((300,300), dtype=np.uint8)

# %%
plt.imsave("negra.jpg", negra)

# %%
plt.show(np.ones((300,300), dtype=np.uint8))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Ale Escallada\UP\PYTHON\Procesamiento_de_imagenes\Semana4\primeraImagen.ipynb Celda 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ale%20Escallada/UP/PYTHON/Procesamiento_de_imagenes/Semana4/primeraImagen.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> plt.show(np.ones((300,300), dtype=np.uint8))
#
# File c:\Python311\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib_inline\backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
# ...

# %%
blanca = np.ones((300,300),dtype=np.uint8)*255

# %%
cv.imwrite("blanca.jpg", blanca)
# Out:
# True

# %%
plt.imsave("blanca_plt.jpg", blanca)

# %%
basket = cv.imread(r"c:\Users\Ale Escallada\OneDrive\Documentos\imagenesPI\basketball1.png")

# %%
basket.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(basket)
